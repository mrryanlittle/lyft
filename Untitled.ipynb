# %%
import pandas as pd
import numpy as np

# %%
payments = "data/payments_to_user.csv"
data = pd.read_csv(payments)

# %%
pay_df = pd.DataFrame(data, columns = ["pay_period","amount","currency","payout_type","processed_at","instant_pay","express_pay","weekly_pay"])
pay_df
# Out:
#                   pay_period  amount currency payout_type  \
# 0    2022-01-10 11:00:00 UTC   112.0      USD     express
# 1    2021-11-15 11:00:00 UTC    47.0      USD     express
# 2    2021-11-15 11:00:00 UTC   105.0      USD     express
# 3    2021-10-11 10:00:00 UTC    97.0      USD     express
# 4    2021-10-18 10:00:00 UTC     4.0      USD     express
# ..                       ...     ...      ...         ...
# 313  2022-02-21 11:00:00 UTC   194.0      USD     express
# 314  2021-12-27 11:00:00 UTC   173.0      USD     express
# 315  2022-03-21 10:00:00 UTC   244.0      USD     express
# 316  2021-07-05 10:00:00 UTC   203.0      USD      weekly
# 317  2021-10-11 10:00:00 UTC   114.0      USD     express
#
#                 processed_at  instant_pay  express_pay  weekly_pay
# 0    2022-01-15 04:57:17 UTC          NaN          NaN         NaN
# 1    2021-11-18 01:27:26 UTC          NaN          NaN         NaN
# ...

# %% [markdown]
# ### CREATE NEW DATAFRAME FOR EACH PAYTYPE

# %%
pay_df.sort_values(by="pay_period")
# Out:
#                   pay_period  amount currency payout_type  \
# 252  2021-06-28 10:00:00 UTC   278.0      USD      weekly
# 316  2021-07-05 10:00:00 UTC   203.0      USD      weekly
# 213  2021-07-12 10:00:00 UTC   393.0      USD      weekly
# 228  2021-07-19 10:00:00 UTC     NaN      USD      weekly
# 206  2021-07-26 10:00:00 UTC     2.0      USD      weekly
# ..                       ...     ...      ...         ...
# 25   2022-05-30 10:00:00 UTC     3.0      USD     instant
# 26   2022-05-30 10:00:00 UTC     3.0      USD     instant
# 62   2022-05-30 10:00:00 UTC     3.0      USD     instant
# 17   2022-05-30 10:00:00 UTC     2.0      USD     instant
# 31   2022-05-30 10:00:00 UTC    10.0      USD     instant
#
#                 processed_at  instant_pay  express_pay  weekly_pay
# 252  2021-07-06 13:37:50 UTC          NaN          NaN         NaN
# 316  2021-07-13 13:29:09 UTC          NaN          NaN         NaN
# ...

# %%
#express_pay = []
#instant_pay = []
#weekly_pay = []

#for value in pay_df["payout_type"]:
#    if value == "express":
#        express_pay.append(pay_df["amount"])
#    if value == "instant":
#        instant_pay.append(pay_df["amount"])
#    if value == "weekly":
#        weekly_pay.append(pay_df["amount"])

# %%
#pay_df["pay_period","amount","currency","payout_type","processed_at","instant_pay","express_pay","weekly_pay"] = instant_pay, express_pay, weekly_pay
